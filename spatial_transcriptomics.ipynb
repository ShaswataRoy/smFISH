# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
plt.style.use('seaborn-whitegrid')
# Out:
# /var/folders/x2/w03h49dx10vd2h81y3q_4tzh0000gn/T/ipykernel_31927/2414357448.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
data_01 = pd.read_csv("GBP5 csv files/221205-Hela-IFNG-Reinduction-0h-1_1ch1_spots.csv")

# %%
gbp5_reinduction_0h = pd.read_csv("GBP5 csv files/221205-Hela-IFNG-Reinduction-0h-1_1ch2_spots.csv")
gapdh_reinduction_0h = pd.read_csv("GBP5 csv files/221205-Hela-IFNG-Reinduction-0h-1_1ch1_spots.csv")
gbp5_reinduction_1h = pd.read_csv("GBP5 csv files/221228-Hela-IFNG-Reinduction-1h-1_1ch2_spots.csv")
gapdh_reinduction_1h = pd.read_csv("GBP5 csv files/221228-Hela-IFNG-Reinduction-1h-1_1ch1_spots.csv")
gbp5_reinduction_2h = pd.read_csv("GBP5 csv files/230101-Hela-IFNG-Reinduction-2h-2_1ch2_spots.csv")
gapdh_reinduction_2h = pd.read_csv("GBP5 csv files/230101-Hela-IFNG-Reinduction-2h-2_1ch1_spots.csv")
gbp5_reinduction_4h = pd.read_csv("GBP5 csv files/221227-Hela-IFNG-Reinduction-4h-2_1ch2_spots.csv")
gapdh_reinduction_4h = pd.read_csv("GBP5 csv files/221227-Hela-IFNG-Reinduction-4h-2_1ch1_spots.csv")
gbp5_reinduction_8h = pd.read_csv("GBP5 csv files/230105-Hela-IFNG-Reinduction-8h-2_1ch1_spots.csv")
gapdh_reinduction_8h = pd.read_csv("GBP5 csv files/230105-Hela-IFNG-Reinduction-8h-2_1ch1_spots.csv")
gbp5_reinduction_16h = pd.read_csv("GBP5 csv files/230214-Hela-IFNG-Reinduction-16h-2_3ch2_spots.csv")
gapdh_reinduction_16h = pd.read_csv("GBP5 csv files/230214-Hela-IFNG-Reinduction-16h-2_3ch1_spots.csv")
gbp5_reinduction_24h = pd.read_csv("GBP5 csv files/230215-Hela-IFNG-Reinduction-24h-3_3ch2_spots.csv")
gapdh_reinduction_24h = pd.read_csv("GBP5 csv files/230215-Hela-IFNG-Reinduction-24h-3_3ch1_spots.csv")

# %%
gapdh_reinduction = [gapdh_reinduction_0h, gapdh_reinduction_1h, gapdh_reinduction_2h, gapdh_reinduction_4h, gapdh_reinduction_8h, gapdh_reinduction_16h, gapdh_reinduction_24h]
gpb5_reinduction = [gbp5_reinduction_0h, gbp5_reinduction_1h, gbp5_reinduction_2h, gbp5_reinduction_4h, gbp5_reinduction_8h, gbp5_reinduction_16h, gbp5_reinduction_24h]

# %%
gbp5_reinduction_24h
# Out:
#        Unnamed: 0       x       y  sigma    r  peak  tile  cell
# 0               0   855.0   682.0    1.5  4.5   166    41    -1
# 1               1   362.0  1353.0    1.0  3.0   162    41    -1
# 2               2   463.0  1252.0    1.5  4.5   147    41    -1
# 3               3   308.0  1438.0    2.0  6.0   163    41    -1
# 4               4   142.0  1225.0    1.5  4.5   138    41    -1
# ...           ...     ...     ...    ...  ...   ...   ...   ...
# 98473         168  1543.0  1283.0    1.5  4.5   145    97    -1
# 98474         169   696.0   865.0    1.0  3.0   143    97    -1
# 98475         170  1136.0  1071.0    1.5  4.5   167    97    -1
# 98476         171  1413.0  1229.0    1.0  3.0   147    97    -1
# 98477         172  1330.0  1092.0    2.0  6.0   172    97    -1
#
# [98478 rows x 8 columns]

# %%
# sns.histplot(gapdh_reinduction_8h.groupby(["tile","cell"]).size().to_numpy(),label="8 h",alpha=0.2).set(xlim=(0,6000))
sns.histplot(gapdh_reinduction_24h.groupby(["tile","cell"]).size().to_numpy(),label="24 h",alpha=0.2).set(xlim=(0,6000))
plt.legend()
plt.title("Gapdh reinduction")
plt.xlabel("Counts")
plt.ylabel("Frequency")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
data = gbp5_reinduction_24h.groupby(["tile","cell"]).size()

# %%
gbp5_reinduction_24h[gbp5_reinduction_24h["cell"]==-1]
# Out:
#        Unnamed: 0       x       y  sigma    r  peak  tile  cell
# 0               0   855.0   682.0    1.5  4.5   166    41    -1
# 1               1   362.0  1353.0    1.0  3.0   162    41    -1
# 2               2   463.0  1252.0    1.5  4.5   147    41    -1
# 3               3   308.0  1438.0    2.0  6.0   163    41    -1
# 4               4   142.0  1225.0    1.5  4.5   138    41    -1
# ...           ...     ...     ...    ...  ...   ...   ...   ...
# 98473         168  1543.0  1283.0    1.5  4.5   145    97    -1
# 98474         169   696.0   865.0    1.0  3.0   143    97    -1
# 98475         170  1136.0  1071.0    1.5  4.5   167    97    -1
# 98476         171  1413.0  1229.0    1.0  3.0   147    97    -1
# 98477         172  1330.0  1092.0    2.0  6.0   172    97    -1
#
# [98478 rows x 8 columns]

# %%
sns.histplot(gbp5_reinduction_2h.groupby(["tile","cell"]).size().to_numpy(),label="2 h",alpha=0.2)
plt.legend()
plt.title("GBP5 reinduction")
plt.xlabel("Counts")
plt.ylabel("Frequency")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
gbp5_reinduction_0h.groupby(["tile","cell"]).size().to_numpy().sum()
# Out:
# 1261

# %%
sns.kdeplot(gbp5_reinduction_0h.groupby(["tile","cell"]).size().to_numpy(),label="0 h",alpha=0.5)

sns.kdeplot(gbp5_reinduction_1h.groupby(["tile","cell"]).size().to_numpy(),label="1 h",alpha=0.5)
sns.kdeplot(gbp5_reinduction_2h.groupby(["tile","cell"]).size().to_numpy(),label="2 h",alpha=0.5)
sns.kdeplot(gbp5_reinduction_4h.groupby(["tile","cell"]).size().to_numpy(),label="4 h",alpha=0.5)
sns.kdeplot(gbp5_reinduction_8h.groupby(["tile","cell"]).size().to_numpy(),label="8 h",alpha=0.5)
sns.kdeplot(gbp5_reinduction_16h.groupby(["tile","cell"]).size().to_numpy(),label="16 h",alpha=0.5)

plt.xlim([0,1000])
plt.ylim([0,0.02])
plt.legend()
plt.title("GBP5 reinduction")
plt.xlabel("Counts")
plt.ylabel("Frequency")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.kdeplot(gbp5_reinduction_8h.groupby(["tile","cell"]).size().to_numpy(),label="8 h",alpha=0.5)
sns.kdeplot(gbp5_reinduction_16h.groupby(["tile","cell"]).size().to_numpy(),label="16 h",alpha=0.5)
sns.kdeplot(gbp5_reinduction_24h.groupby(["tile","cell"]).size().to_numpy(),label="24 h",alpha=0.5)
plt.xlim([0,6000])
plt.legend()
plt.title("GBP5 reinduction")
plt.xlabel("Counts")
plt.ylabel("Frequency")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
sns.histplot(gbp5_reinduction_1h.groupby(["tile","cell"]).size().to_numpy(),stat="probability",binwidth=20,label="1 h",alpha=0.2)
sns.histplot(gbp5_reinduction_2h.groupby(["tile","cell"]).size().to_numpy(),stat="probability",binwidth=20,label="2 h",alpha=0.2)
# sns.histplot(gbp5_reinduction_4h.groupby(["tile","cell"]).size().to_numpy(),stat="probability",binwidth=20,label="4 h",alpha=0.2)

plt.legend()
plt.title("GBP5 reinduction")
plt.xlabel("Counts")
plt.ylabel("Frequency")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
sns.histplot(gbp5_reinduction_4h.groupby(["tile","cell"]).size().to_numpy(),stat="probability",binwidth=20,label="4 h",alpha=0.2)

plt.legend()
plt.title("GBP5 reinduction")
plt.xlabel("Counts")
plt.ylabel("Frequency")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
sns.histplot(gbp5_reinduction_24h.groupby(["tile","cell"]).size().to_numpy(),label="24 h",alpha=0.2,bins=5000).set(xlim=(0,200))
plt.legend()
plt.title("GBP5 reinduction")
plt.xlabel("Counts")
plt.ylabel("Frequency")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(gapdh_reinduction_0h.groupby(["tile","cell"]).size().to_numpy(),label="0 h").set(xlim=(0))
sns.kdeplot(gapdh_reinduction_1h.groupby(["tile","cell"]).size().to_numpy(),label="1 h").set(xlim=(0))
sns.kdeplot(gapdh_reinduction_2h.groupby(["tile","cell"]).size().to_numpy(),label="2 h").set(xlim=(0))
sns.kdeplot(gapdh_reinduction_4h.groupby(["tile","cell"]).size().to_numpy(),label="4 h").set(xlim=(0))
sns.kdeplot(gapdh_reinduction_8h.groupby(["tile","cell"]).size().to_numpy(),label="8 h").set(xlim=(0))
sns.kdeplot(gapdh_reinduction_16h.groupby(["tile","cell"]).size().to_numpy(),label="16 h").set(xlim=(0))
sns.kdeplot(gapdh_reinduction_24h.groupby(["tile","cell"]).size().to_numpy(),label="24 h").set(xlim=(0))
plt.legend()
plt.title("Gapdh reinduction")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(gbp5_reinduction_0h.groupby(["tile","cell"]).size().to_numpy(),label="0 h")
sns.kdeplot(gbp5_reinduction_1h.groupby(["tile","cell"]).size().to_numpy(),label="1 h").set(xlim=(0))
sns.kdeplot(gbp5_reinduction_2h.groupby(["tile","cell"]).size().to_numpy(),label="2 h").set(xlim=(0))
sns.kdeplot(gbp5_reinduction_4h.groupby(["tile","cell"]).size().to_numpy(),label="4 h").set(xlim=(0))
sns.kdeplot(gbp5_reinduction_8h.groupby(["tile","cell"]).size().to_numpy(),label="8 h").set(xlim=(0))
sns.kdeplot(gbp5_reinduction_16h.groupby(["tile","cell"]).size().to_numpy(),label="16 h").set(xlim=(0))
sns.kdeplot(gbp5_reinduction_24h.groupby(["tile","cell"]).size().to_numpy(),label="24 h").set(xlim=(0))
plt.legend()
plt.title("GBP5 reinduction")
# Out:
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/shaswataroy/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
gapdh_reinduction_mean = np.array([np.mean(x.groupby(["tile","cell"]).size().to_numpy()) for x in gapdh_reinduction])
gapdh_reinduction_std = np.array([np.std(x.groupby(["tile","cell"]).size().to_numpy()) for x in gapdh_reinduction])

plt.xlabel("Mean")
plt.ylabel("Standard deviation")
plt.plot(np.arange(0,15000,100),np.arange(0,15000,100))

# %%
gbp5_reinduction_mean = np.array([np.mean(x.groupby(["tile","cell"]).size().to_numpy()) for x in gpb5_reinduction])
gbp5_reinduction_std = np.array([np.std(x.groupby(["tile","cell"]).size().to_numpy()) for x in gpb5_reinduction])
plt.plot(gbp5_reinduction_mean, gbp5_reinduction_std,'ro',label="GBP5 Reinduction")
plt.plot(gapdh_reinduction_mean, gapdh_reinduction_std,'go',label="GAPDH Reinduction")
plt.xlabel("Mean")
plt.ylabel("Standard deviation")
plt.plot(np.arange(0,8000,100),np.arange(0,8000,100))
plt.xlim(0,25000)
plt.ylim(0,25000)
plt.legend()

# %%
data_01_40 = data_01[data_01["tile"]==44]

# %%
data_01_tile = data_01[data_01["cell"]!=-1].groupby(["tile","cell"])

# %%
data_01[data_01["cell"]!=-1]
# Out:
#         Unnamed: 0       x       y  sigma    r  peak  tile  cell
# 0                0   568.0  1292.0    1.5  4.5  1584    36     1
# 1                1   581.0  1342.0    1.0  3.0  1186    36     1
# 2                2   727.0  1351.0    1.0  3.0  1159    36     1
# 3                3   578.0  1091.0    1.0  3.0  1108    36     1
# 4                4   545.0  1300.0    1.5  4.5   997    36     1
# ...            ...     ...     ...    ...  ...   ...   ...   ...
# 256590        3156  1717.0  1830.0    1.0  3.0   446    97     0
# 256591        3157   978.0   746.0    1.0  3.0   600    97     2
# 256592        3158   376.0   871.0    1.0  3.0   322    97     0
# 256593        3159  1783.0  1509.0    3.0  9.0   373    97     0
# 256594        3160  1757.0   209.0    1.5  4.5   369    97     0
#
# [238049 rows x 8 columns]

# %%
plt.hist(data_01_tile.size().to_numpy())
# Out:
# (array([79., 77., 41.,  9.,  9.,  4.,  3.,  0.,  0.,  1.]),
#  array([  24. ,  633.1, 1242.2, 1851.3, 2460.4, 3069.5, 3678.6, 4287.7,
#         4896.8, 5505.9, 6115. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(data_01_40["x"],data_01_40["y"],c = data_01_40["cell"])
